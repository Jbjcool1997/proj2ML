# %%
pip install azureml-sdk==1.59.0
# Out:
# Collecting azureml-sdk==1.59.0
#   Using cached azureml_sdk-1.59.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting azureml-core~=1.59.0 (from azureml-sdk==1.59.0)
#   Using cached azureml_core-1.59.0.post2-py3-none-any.whl.metadata (3.4 kB)
# Collecting azureml-dataset-runtime~=1.59.0 (from azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk==1.59.0)
#   Using cached azureml_dataset_runtime-1.59.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting azureml-train-core~=1.59.0 (from azureml-sdk==1.59.0)
#   Using cached azureml_train_core-1.59.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting azureml-train-automl-client~=1.59.0 (from azureml-sdk==1.59.0)
#   Using cached azureml_train_automl_client-1.59.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting azureml-pipeline~=1.59.0 (from azureml-sdk==1.59.0)
#   Using cached azureml_pipeline-1.59.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pytz in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (2025.2)
# Requirement already satisfied: backports.tempfile in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (1.0)
# Requirement already satisfied: pathspec<1.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (0.12.1)
# Requirement already satisfied: requests<3.0.0,>=2.19.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.59.0->azureml-sdk==1.59.0) (2.32.3)
# Requirement already satisfied: msal<2.0.0,>=1.15.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (1.32.3)
# Requirement already satisfied: msal-extensions<=2.0.0,>=0.3.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (1.3.1)
# Requirement already satisfied: knack<0.13.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (0.12.0)
# Requirement already satisfied: azure-core<2.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (1.34.0)
# Requirement already satisfied: pkginfo in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (1.12.1.2)
# Requirement already satisfied: argcomplete<4 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (3.6.2)
# Requirement already satisfied: humanfriendly<11.0,>=4.7 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (10.0)
# Requirement already satisfied: paramiko<4.0.0,>=2.0.8 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (3.5.1)
# Requirement already satisfied: azure-mgmt-resource<=24.0.0,>=15.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (23.3.0)
# Requirement already satisfied: azure-mgmt-containerregistry<11,>=8.2.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (10.3.0)
# Requirement already satisfied: azure-mgmt-storage<=22.0.0,>=16.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (22.0.0)
# Requirement already satisfied: azure-mgmt-keyvault<11.0.0,>=0.40.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (10.3.1)
# Requirement already satisfied: azure-mgmt-authorization<5,>=0.40.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (4.0.0)
# Requirement already satisfied: azure-mgmt-network<=29.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (28.1.0)
# Requirement already satisfied: azure-graphrbac<1.0.0,>=0.40.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (0.61.2)
# Requirement already satisfied: azure-common<2.0.0,>=1.1.12 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (1.1.28)
# Requirement already satisfied: msrest<=0.7.1,>=0.5.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (0.7.1)
# Requirement already satisfied: msrestazure<=0.7,>=0.4.33 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (0.6.4.post1)
# Requirement already satisfied: urllib3<3.0.0,>1.26.17 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (1.26.20)
# Requirement already satisfied: packaging<=25.0,>=20.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (24.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (2.9.0.post0)
# Requirement already satisfied: ndg-httpsclient<=0.5.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (0.5.1)
# Requirement already satisfied: SecretStorage<4.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (3.3.3)
# Requirement already satisfied: jsonpickle<5.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (4.0.5)
# Requirement already satisfied: contextlib2<22.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (21.6.0)
# Requirement already satisfied: docker<8.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (7.1.0)
# Requirement already satisfied: PyJWT<3.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (2.10.1)
# Requirement already satisfied: adal<=1.2.7,>=1.2.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (1.2.7)
# Requirement already satisfied: pyopenssl<25.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (24.3.0)
# Requirement already satisfied: jmespath<2.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk==1.59.0) (0.10.0)
# Requirement already satisfied: cryptography>=1.1.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from adal<=1.2.7,>=1.2.0->azureml-core~=1.59.0->azureml-sdk==1.59.0) (44.0.3)
# Requirement already satisfied: six>=1.11.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azure-core<2.0.0->azureml-core~=1.59.0->azureml-sdk==1.59.0) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azure-core<2.0.0->azureml-core~=1.59.0->azureml-sdk==1.59.0) (4.13.2)
# Requirement already satisfied: isodate<1.0.0,>=0.6.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azure-mgmt-authorization<5,>=0.40.0->azureml-core~=1.59.0->azureml-sdk==1.59.0) (0.7.2)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.3.2 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azure-mgmt-authorization<5,>=0.40.0->azureml-core~=1.59.0->azureml-sdk==1.59.0) (1.5.0)
# Requirement already satisfied: azureml-dataprep<5.2.0a,>=5.1.0a in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk==1.59.0) (5.1.6)
# Requirement already satisfied: pyarrow>=0.17.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk==1.59.0) (14.0.2)
# Requirement already satisfied: numpy!=1.19.3,<1.24 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk==1.59.0) (1.23.5)
# Requirement already satisfied: azureml-dataprep-native<42.0.0,>=41.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk==1.59.0) (41.0.0)
# Requirement already satisfied: azureml-dataprep-rslex~=2.22.2dev0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk==1.59.0) (2.22.5)
# Requirement already satisfied: cloudpickle<3.0.0,>=1.1.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk==1.59.0) (2.2.1)
# Requirement already satisfied: azure-identity>=1.7.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk==1.59.0) (1.22.0)
# Requirement already satisfied: jsonschema in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk==1.59.0) (4.23.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.1.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk==1.59.0) (6.0.2)
# Requirement already satisfied: fusepy<4.0.0,>=3.0.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk==1.59.0) (3.0.1)
# Collecting azureml-pipeline-core~=1.59.0 (from azureml-pipeline~=1.59.0->azureml-sdk==1.59.0)
#   Using cached azureml_pipeline_core-1.59.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting azureml-pipeline-steps~=1.59.0 (from azureml-pipeline~=1.59.0->azureml-sdk==1.59.0)
#   Using cached azureml_pipeline_steps-1.59.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting azureml-automl-core~=1.59.0 (from azureml-train-automl-client~=1.59.0->azureml-sdk==1.59.0)
#   Using cached azureml_automl_core-1.59.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting azureml-telemetry~=1.59.0 (from azureml-train-automl-client~=1.59.0->azureml-sdk==1.59.0)
#   Using cached azureml_telemetry-1.59.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: importlib-metadata<=8.2.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-core~=1.59.0->azureml-train-automl-client~=1.59.0->azureml-sdk==1.59.0) (8.2.0)
# Requirement already satisfied: importlib-resources<=6.4.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-core~=1.59.0->azureml-train-automl-client~=1.59.0->azureml-sdk==1.59.0) (6.4.0)
# Requirement already satisfied: applicationinsights in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-telemetry~=1.59.0->azureml-train-automl-client~=1.59.0->azureml-sdk==1.59.0) (0.11.10)
# Collecting azureml-train-restclients-hyperdrive~=1.59.0 (from azureml-train-core~=1.59.0->azureml-sdk==1.59.0)
#   Using cached azureml_train_restclients_hyperdrive-1.59.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: zipp>=0.5 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from importlib-metadata<=8.2.0->azureml-automl-core~=1.59.0->azureml-train-automl-client~=1.59.0->azureml-sdk==1.59.0) (3.21.0)
# Requirement already satisfied: pygments in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from knack<0.13.0->azureml-core~=1.59.0->azureml-sdk==1.59.0) (2.19.1)
# Requirement already satisfied: tabulate in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from knack<0.13.0->azureml-core~=1.59.0->azureml-sdk==1.59.0) (0.9.0)
# Requirement already satisfied: cffi>=1.12 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from cryptography>=1.1.0->adal<=1.2.7,>=1.2.0->azureml-core~=1.59.0->azureml-sdk==1.59.0) (1.17.1)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.59.0->azureml-sdk==1.59.0) (2025.4.26)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.59.0->azureml-sdk==1.59.0) (2.0.0)
# Requirement already satisfied: pyasn1>=0.1.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from ndg-httpsclient<=0.5.1->azureml-core~=1.59.0->azureml-sdk==1.59.0) (0.6.1)
# Requirement already satisfied: bcrypt>=3.2 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from paramiko<4.0.0,>=2.0.8->azureml-core~=1.59.0->azureml-sdk==1.59.0) (4.3.0)
# Requirement already satisfied: pynacl>=1.5 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from paramiko<4.0.0,>=2.0.8->azureml-core~=1.59.0->azureml-sdk==1.59.0) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from requests<3.0.0,>=2.19.1->requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.59.0->azureml-sdk==1.59.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from requests<3.0.0,>=2.19.1->requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.59.0->azureml-sdk==1.59.0) (3.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.59.0->azureml-sdk==1.59.0) (1.7.1)
# Requirement already satisfied: jeepney>=0.6 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from SecretStorage<4.0.0->azureml-core~=1.59.0->azureml-sdk==1.59.0) (0.9.0)
# Requirement already satisfied: pycparser in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=1.1.0->adal<=1.2.7,>=1.2.0->azureml-core~=1.59.0->azureml-sdk==1.59.0) (2.22)
# Requirement already satisfied: oauthlib>=3.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from requests-oauthlib>=0.5.0->msrest<=0.7.1,>=0.5.1->azureml-core~=1.59.0->azureml-sdk==1.59.0) (3.2.2)
# Requirement already satisfied: backports.weakref in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from backports.tempfile->azureml-core~=1.59.0->azureml-sdk==1.59.0) (1.0.post1)
# Requirement already satisfied: attrs>=22.2.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk==1.59.0) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk==1.59.0) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk==1.59.0) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk==1.59.0) (0.24.0)
# Using cached azureml_sdk-1.59.0-py3-none-any.whl (2.7 kB)
# Using cached azureml_core-1.59.0.post2-py3-none-any.whl (3.3 MB)
# Using cached azureml_dataset_runtime-1.59.0-py3-none-any.whl (2.2 kB)
# Using cached azureml_pipeline-1.59.0-py3-none-any.whl (2.4 kB)
# Using cached azureml_pipeline_core-1.59.0-py3-none-any.whl (313 kB)
# Using cached azureml_pipeline_steps-1.59.0-py3-none-any.whl (69 kB)
# Using cached azureml_train_automl_client-1.59.0-py3-none-any.whl (137 kB)
# Using cached azureml_automl_core-1.59.0-py3-none-any.whl (245 kB)
# Using cached azureml_telemetry-1.59.0-py3-none-any.whl (30 kB)
# Using cached azureml_train_core-1.59.0-py3-none-any.whl (8.6 MB)
# Using cached azureml_train_restclients_hyperdrive-1.59.0-py3-none-any.whl (18 kB)
# Installing collected packages: azureml-train-restclients-hyperdrive, azureml-core, azureml-telemetry, azureml-pipeline-core, azureml-train-core, azureml-dataset-runtime, azureml-automl-core, azureml-train-automl-client, azureml-pipeline-steps, azureml-pipeline, azureml-sdk
#   Attempting uninstall: azureml-train-restclients-hyperdrive
#     Found existing installation: azureml-train-restclients-hyperdrive 1.60.0
#     Uninstalling azureml-train-restclients-hyperdrive-1.60.0:
#       Successfully uninstalled azureml-train-restclients-hyperdrive-1.60.0
#   Attempting uninstall: azureml-core
#     Found existing installation: azureml-core 1.60.0
#     Uninstalling azureml-core-1.60.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/11 [azureml-core]
#       Successfully uninstalled azureml-core-1.60.0━━━━━━━━━━━━  1/11 [azureml-core]
#   Attempting uninstall: azureml-telemetry━━━━━━━━━━━━━━━━━━━━━━━━━  1/11 [azureml-core]
#     Found existing installation: azureml-telemetry 1.60.0━━━━━  1/11 [azureml-core]
#     Uninstalling azureml-telemetry-1.60.0:━━━━━━━━━━━━━━━━━━━━  1/11 [azureml-core]
#       Successfully uninstalled azureml-telemetry-1.60.0━━━━━━━  1/11 [azureml-core]
#   Attempting uninstall: azureml-pipeline-core━━━━━━━━━━━━━━━━━  1/11 [azureml-core]
#     Found existing installation: azureml-pipeline-core 1.60.0━  1/11 [azureml-core]
#     Uninstalling azureml-pipeline-core-1.60.0:━━━━━━━━━━━━━━━━  1/11 [azureml-core]
#       Successfully uninstalled azureml-pipeline-core-1.60.0━━━━━━━  3/11 [azureml-pipeline-core]
#   Attempting uninstall: azureml-train-core━━━━━━━━━━━━━━━━━━━━━━━━  3/11 [azureml-pipeline-core]
#     Found existing installation: azureml-train-core 1.60.0━━━━  3/11 [azureml-pipeline-core]
#     Uninstalling azureml-train-core-1.60.0:━━━━━━━━━━━━━━━━━━━  3/11 [azureml-pipeline-core]
#       Successfully uninstalled azureml-train-core-1.60.0━━━━━━━━━━  4/11 [azureml-train-core]
#   Attempting uninstall: azureml-dataset-runtime━━━━━━━━━━━━━━━  4/11 [azureml-train-core]
#     Found existing installation: azureml-dataset-runtime 1.60.0  4/11 [azureml-train-core]
#     Uninstalling azureml-dataset-runtime-1.60.0:━━━━━━━━━━━━━━  4/11 [azureml-train-core]
#       Successfully uninstalled azureml-dataset-runtime-1.60.0━  4/11 [azureml-train-core]
#   Attempting uninstall: azureml-automl-core━━━━━━━━━━━━━━━━━━━  4/11 [azureml-train-core]
#     Found existing installation: azureml-automl-core 1.60.0━━━  4/11 [azureml-train-core]
#     Uninstalling azureml-automl-core-1.60.0:━━━━━━━━━━━━━━━━━━  4/11 [azureml-train-core]
#       Successfully uninstalled azureml-automl-core-1.60.0━━━━━━━━━  6/11 [azureml-automl-core]
#   Attempting uninstall: azureml-train-automl-client━━━━━━━━━━━━━━━  6/11 [azureml-automl-core]
#     Found existing installation: azureml-train-automl-client 1.60.0 6/11 [azureml-automl-core]
#     Uninstalling azureml-train-automl-client-1.60.0:━━━━━━━━━━  6/11 [azureml-automl-core]
#       Successfully uninstalled azureml-train-automl-client-1.60.0━  7/11 [azureml-train-automl-client]
#   Attempting uninstall: azureml-pipeline-stepsm━━━━━━━━━━━━━━  7/11 [azureml-train-automl-client]
#     Found existing installation: azureml-pipeline-steps 1.60.0  7/11 [azureml-train-automl-client]
#     Uninstalling azureml-pipeline-steps-1.60.0:m━━━━━━━━━━━━━━  7/11 [azureml-train-automl-client]
#       Successfully uninstalled azureml-pipeline-steps-1.60.0━━━━━━  8/11 [azureml-pipeline-steps]]
#   Attempting uninstall: azureml-pipeline0m╺━━━━━━━━━━  8/11 [azureml-pipeline-steps]
#     Found existing installation: azureml-pipeline 1.60.0━━━━━━  8/11 [azureml-pipeline-steps]
#     Uninstalling azureml-pipeline-1.60.0:m╺━━━━━━━━━━  8/11 [azureml-pipeline-steps]
#       Successfully uninstalled azureml-pipeline-1.60.0━━━━━━━━  8/11 [azureml-pipeline-steps]
#   Attempting uninstall: azureml-sdk0m╺━━━━━━━━━━  8/11 [azureml-pipeline-steps]
#     Found existing installation: azureml-sdk 1.60.0m━━━━━━━━━━  8/11 [azureml-pipeline-steps]
#     Uninstalling azureml-sdk-1.60.0:m╺━━━━━━━━━━  8/11 [azureml-pipeline-steps]
#       Successfully uninstalled azureml-sdk-1.60.090m━━━━━━━━━━  8/11 [azureml-pipeline-steps]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/11 [azureml-sdk] [azureml-pipeline-steps]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# azureml-automl-runtime 1.60.0 requires azureml-automl-core~=1.60.0, but you have azureml-automl-core 1.59.0 which is incompatible.
# azureml-automl-runtime 1.60.0 requires azureml-dataset-runtime[fuse,pandas]~=1.60.0, but you have azureml-dataset-runtime 1.59.0 which is incompatible.
# azureml-contrib-notebook 1.60.0 requires azureml-core~=1.60.0, but you have azureml-core 1.59.0.post2 which is incompatible.
# azureml-contrib-notebook 1.60.0 requires azureml-pipeline-core~=1.60.0, but you have azureml-pipeline-core 1.59.0 which is incompatible.
# azureml-interpret 1.60.0 requires azureml-core~=1.60.0, but you have azureml-core 1.59.0.post2 which is incompatible.
# azureml-responsibleai 1.60.0 requires azureml-core~=1.60.0, but you have azureml-core 1.59.0.post2 which is incompatible.
# azureml-responsibleai 1.60.0 requires azureml-dataset-runtime~=1.60.0, but you have azureml-dataset-runtime 1.59.0 which is incompatible.
# azureml-responsibleai 1.60.0 requires azureml-telemetry~=1.60.0, but you have azureml-telemetry 1.59.0 which is incompatible.
# azureml-train-automl 1.60.0 requires azureml-automl-core~=1.60.0, but you have azureml-automl-core 1.59.0 which is incompatible.
# azureml-train-automl 1.60.0 requires azureml-dataset-runtime[fuse,pandas]~=1.60.0, but you have azureml-dataset-runtime 1.59.0 which is incompatible.
# azureml-train-automl 1.60.0 requires azureml-train-automl-client~=1.60.0, but you have azureml-train-automl-client 1.59.0 which is incompatible.
# azureml-train-automl-runtime 1.60.0 requires azureml-automl-core~=1.60.0, but you have azureml-automl-core 1.59.0 which is incompatible.
# azureml-train-automl-runtime 1.60.0 requires azureml-core~=1.60.0, but you have azureml-core 1.59.0.post2 which is incompatible.
# azureml-train-automl-runtime 1.60.0 requires azureml-dataset-runtime[fuse,pandas]~=1.60.0, but you have azureml-dataset-runtime 1.59.0 which is incompatible.
# azureml-train-automl-runtime 1.60.0 requires azureml-telemetry~=1.60.0, but you have azureml-telemetry 1.59.0 which is incompatible.
# azureml-train-automl-runtime 1.60.0 requires azureml-train-automl-client~=1.60.0, but you have azureml-train-automl-client 1.59.0 which is incompatible.
# azureml-training-tabular 1.60.0 requires azureml-automl-core~=1.60.0, but you have azureml-automl-core 1.59.0 which is incompatible.
# azureml-widgets 1.60.0 requires azureml-core~=1.60.0, but you have azureml-core 1.59.0.post2 which is incompatible.
# azureml-widgets 1.60.0 requires azureml-telemetry~=1.60.0, but you have azureml-telemetry 1.59.0 which is incompatible.
# Successfully installed azureml-automl-core-1.59.0 azureml-core-1.59.0.post2 azureml-dataset-runtime-1.59.0 azureml-pipeline-1.59.0 azureml-pipeline-core-1.59.0 azureml-pipeline-steps-1.59.0 azureml-sdk-1.59.0 azureml-telemetry-1.59.0 azureml-train-automl-client-1.59.0 azureml-train-core-1.59.0 azureml-train-restclients-hyperdrive-1.59.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install azureml-sdk
# Out:
# Requirement already satisfied: azureml-sdk in /anaconda/envs/automl-env3/lib/python3.9/site-packages (1.59.0)
# Requirement already satisfied: azureml-core~=1.59.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-sdk) (1.59.0.post2)
# Requirement already satisfied: azureml-dataset-runtime~=1.59.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk) (1.59.0)
# Requirement already satisfied: azureml-train-core~=1.59.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-sdk) (1.59.0)
# Requirement already satisfied: azureml-train-automl-client~=1.59.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-sdk) (1.59.0)
# Requirement already satisfied: azureml-pipeline~=1.59.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-sdk) (1.59.0)
# Requirement already satisfied: pytz in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (2025.2)
# Requirement already satisfied: backports.tempfile in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (1.0)
# Requirement already satisfied: pathspec<1.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (0.12.1)
# Requirement already satisfied: requests<3.0.0,>=2.19.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.59.0->azureml-sdk) (2.32.3)
# Requirement already satisfied: msal<2.0.0,>=1.15.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (1.32.3)
# Requirement already satisfied: msal-extensions<=2.0.0,>=0.3.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (1.3.1)
# Requirement already satisfied: knack<0.13.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (0.12.0)
# Requirement already satisfied: azure-core<2.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (1.34.0)
# Requirement already satisfied: pkginfo in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (1.12.1.2)
# Requirement already satisfied: argcomplete<4 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (3.6.2)
# Requirement already satisfied: humanfriendly<11.0,>=4.7 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (10.0)
# Requirement already satisfied: paramiko<4.0.0,>=2.0.8 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (3.5.1)
# Requirement already satisfied: azure-mgmt-resource<=24.0.0,>=15.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (23.3.0)
# Requirement already satisfied: azure-mgmt-containerregistry<11,>=8.2.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (10.3.0)
# Requirement already satisfied: azure-mgmt-storage<=22.0.0,>=16.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (22.0.0)
# Requirement already satisfied: azure-mgmt-keyvault<11.0.0,>=0.40.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (10.3.1)
# Requirement already satisfied: azure-mgmt-authorization<5,>=0.40.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (4.0.0)
# Requirement already satisfied: azure-mgmt-network<=29.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (28.1.0)
# Requirement already satisfied: azure-graphrbac<1.0.0,>=0.40.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (0.61.2)
# Requirement already satisfied: azure-common<2.0.0,>=1.1.12 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (1.1.28)
# Requirement already satisfied: msrest<=0.7.1,>=0.5.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (0.7.1)
# Requirement already satisfied: msrestazure<=0.7,>=0.4.33 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (0.6.4.post1)
# Requirement already satisfied: urllib3<3.0.0,>1.26.17 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (1.26.20)
# Requirement already satisfied: packaging<=25.0,>=20.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (24.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (2.9.0.post0)
# Requirement already satisfied: ndg-httpsclient<=0.5.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (0.5.1)
# Requirement already satisfied: SecretStorage<4.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (3.3.3)
# Requirement already satisfied: jsonpickle<5.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (4.0.5)
# Requirement already satisfied: contextlib2<22.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (21.6.0)
# Requirement already satisfied: docker<8.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (7.1.0)
# Requirement already satisfied: PyJWT<3.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (2.10.1)
# Requirement already satisfied: adal<=1.2.7,>=1.2.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (1.2.7)
# Requirement already satisfied: pyopenssl<25.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (24.3.0)
# Requirement already satisfied: jmespath<2.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk) (0.10.0)
# Requirement already satisfied: cryptography>=1.1.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from adal<=1.2.7,>=1.2.0->azureml-core~=1.59.0->azureml-sdk) (44.0.3)
# Requirement already satisfied: six>=1.11.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azure-core<2.0.0->azureml-core~=1.59.0->azureml-sdk) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azure-core<2.0.0->azureml-core~=1.59.0->azureml-sdk) (4.13.2)
# Requirement already satisfied: isodate<1.0.0,>=0.6.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azure-mgmt-authorization<5,>=0.40.0->azureml-core~=1.59.0->azureml-sdk) (0.7.2)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.3.2 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azure-mgmt-authorization<5,>=0.40.0->azureml-core~=1.59.0->azureml-sdk) (1.5.0)
# Requirement already satisfied: azureml-dataprep<5.2.0a,>=5.1.0a in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk) (5.1.6)
# Requirement already satisfied: pyarrow>=0.17.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk) (14.0.2)
# Requirement already satisfied: numpy!=1.19.3,<1.24 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk) (1.23.5)
# Requirement already satisfied: azureml-dataprep-native<42.0.0,>=41.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk) (41.0.0)
# Requirement already satisfied: azureml-dataprep-rslex~=2.22.2dev0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk) (2.22.5)
# Requirement already satisfied: cloudpickle<3.0.0,>=1.1.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk) (2.2.1)
# Requirement already satisfied: azure-identity>=1.7.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk) (1.22.0)
# Requirement already satisfied: jsonschema in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk) (4.23.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.1.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk) (6.0.2)
# Requirement already satisfied: fusepy<4.0.0,>=3.0.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk) (3.0.1)
# Requirement already satisfied: azureml-pipeline-core~=1.59.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-pipeline~=1.59.0->azureml-sdk) (1.59.0)
# Requirement already satisfied: azureml-pipeline-steps~=1.59.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-pipeline~=1.59.0->azureml-sdk) (1.59.0)
# Requirement already satisfied: azureml-automl-core~=1.59.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-train-automl-client~=1.59.0->azureml-sdk) (1.59.0)
# Requirement already satisfied: azureml-telemetry~=1.59.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-train-automl-client~=1.59.0->azureml-sdk) (1.59.0)
# Requirement already satisfied: importlib-metadata<=8.2.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-core~=1.59.0->azureml-train-automl-client~=1.59.0->azureml-sdk) (8.2.0)
# Requirement already satisfied: importlib-resources<=6.4.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-core~=1.59.0->azureml-train-automl-client~=1.59.0->azureml-sdk) (6.4.0)
# Requirement already satisfied: applicationinsights in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-telemetry~=1.59.0->azureml-train-automl-client~=1.59.0->azureml-sdk) (0.11.10)
# Requirement already satisfied: azureml-train-restclients-hyperdrive~=1.59.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-train-core~=1.59.0->azureml-sdk) (1.59.0)
# Requirement already satisfied: zipp>=0.5 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from importlib-metadata<=8.2.0->azureml-automl-core~=1.59.0->azureml-train-automl-client~=1.59.0->azureml-sdk) (3.21.0)
# Requirement already satisfied: pygments in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from knack<0.13.0->azureml-core~=1.59.0->azureml-sdk) (2.19.1)
# Requirement already satisfied: tabulate in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from knack<0.13.0->azureml-core~=1.59.0->azureml-sdk) (0.9.0)
# Requirement already satisfied: cffi>=1.12 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from cryptography>=1.1.0->adal<=1.2.7,>=1.2.0->azureml-core~=1.59.0->azureml-sdk) (1.17.1)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.59.0->azureml-sdk) (2025.4.26)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.59.0->azureml-sdk) (2.0.0)
# Requirement already satisfied: pyasn1>=0.1.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from ndg-httpsclient<=0.5.1->azureml-core~=1.59.0->azureml-sdk) (0.6.1)
# Requirement already satisfied: bcrypt>=3.2 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from paramiko<4.0.0,>=2.0.8->azureml-core~=1.59.0->azureml-sdk) (4.3.0)
# Requirement already satisfied: pynacl>=1.5 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from paramiko<4.0.0,>=2.0.8->azureml-core~=1.59.0->azureml-sdk) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from requests<3.0.0,>=2.19.1->requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.59.0->azureml-sdk) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from requests<3.0.0,>=2.19.1->requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.59.0->azureml-sdk) (3.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.59.0->azureml-sdk) (1.7.1)
# Requirement already satisfied: jeepney>=0.6 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from SecretStorage<4.0.0->azureml-core~=1.59.0->azureml-sdk) (0.9.0)
# Requirement already satisfied: pycparser in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=1.1.0->adal<=1.2.7,>=1.2.0->azureml-core~=1.59.0->azureml-sdk) (2.22)
# Requirement already satisfied: oauthlib>=3.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from requests-oauthlib>=0.5.0->msrest<=0.7.1,>=0.5.1->azureml-core~=1.59.0->azureml-sdk) (3.2.2)
# Requirement already satisfied: backports.weakref in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from backports.tempfile->azureml-core~=1.59.0->azureml-sdk) (1.0.post1)
# Requirement already satisfied: attrs>=22.2.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk) (0.24.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show azureml-sdk
# Out:
# Name: azureml-sdk
# Version: 1.59.0
# Summary: Used to build and run machine learning workflows upon the     Azure Machine Learning service.
# Home-page: https://docs.microsoft.com/python/api/overview/azure/ml/?view=azure-ml-py
# Author: Microsoft Corp
# Author-email:
# License: https://aka.ms/azureml-sdk-license
# Location: /anaconda/envs/automl-env3/lib/python3.9/site-packages
# Requires: azureml-core, azureml-dataset-runtime, azureml-pipeline, azureml-train-automl-client, azureml-train-core
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install 'azureml-sdk[notebooks]
# Out:
# /bin/bash: -c: line 1: unexpected EOF while looking for matching `''
# /bin/bash: -c: line 2: syntax error: unexpected end of file
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install azureml-sdk[automl]
# Out:
# Requirement already satisfied: azureml-sdk[automl] in /anaconda/envs/automl-env3/lib/python3.9/site-packages (1.59.0)
# Requirement already satisfied: azureml-core~=1.59.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-sdk[automl]) (1.59.0.post2)
# Requirement already satisfied: azureml-dataset-runtime~=1.59.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk[automl]) (1.59.0)
# Requirement already satisfied: azureml-train-core~=1.59.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-sdk[automl]) (1.59.0)
# Requirement already satisfied: azureml-train-automl-client~=1.59.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-sdk[automl]) (1.59.0)
# Requirement already satisfied: azureml-pipeline~=1.59.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-sdk[automl]) (1.59.0)
# Collecting azureml-train-automl~=1.59.0 (from azureml-sdk[automl])
#   Using cached azureml_train_automl-1.59.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: pytz in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (2025.2)
# Requirement already satisfied: backports.tempfile in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (1.0)
# Requirement already satisfied: pathspec<1.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (0.12.1)
# Requirement already satisfied: requests<3.0.0,>=2.19.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.59.0->azureml-sdk[automl]) (2.32.3)
# Requirement already satisfied: msal<2.0.0,>=1.15.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (1.32.3)
# Requirement already satisfied: msal-extensions<=2.0.0,>=0.3.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (1.3.1)
# Requirement already satisfied: knack<0.13.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (0.12.0)
# Requirement already satisfied: azure-core<2.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (1.34.0)
# Requirement already satisfied: pkginfo in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (1.12.1.2)
# Requirement already satisfied: argcomplete<4 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (3.6.2)
# Requirement already satisfied: humanfriendly<11.0,>=4.7 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (10.0)
# Requirement already satisfied: paramiko<4.0.0,>=2.0.8 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (3.5.1)
# Requirement already satisfied: azure-mgmt-resource<=24.0.0,>=15.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (23.3.0)
# Requirement already satisfied: azure-mgmt-containerregistry<11,>=8.2.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (10.3.0)
# Requirement already satisfied: azure-mgmt-storage<=22.0.0,>=16.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (22.0.0)
# Requirement already satisfied: azure-mgmt-keyvault<11.0.0,>=0.40.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (10.3.1)
# Requirement already satisfied: azure-mgmt-authorization<5,>=0.40.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (4.0.0)
# Requirement already satisfied: azure-mgmt-network<=29.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (28.1.0)
# Requirement already satisfied: azure-graphrbac<1.0.0,>=0.40.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (0.61.2)
# Requirement already satisfied: azure-common<2.0.0,>=1.1.12 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (1.1.28)
# Requirement already satisfied: msrest<=0.7.1,>=0.5.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (0.7.1)
# Requirement already satisfied: msrestazure<=0.7,>=0.4.33 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (0.6.4.post1)
# Requirement already satisfied: urllib3<3.0.0,>1.26.17 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (1.26.20)
# Requirement already satisfied: packaging<=25.0,>=20.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (24.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (2.9.0.post0)
# Requirement already satisfied: ndg-httpsclient<=0.5.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (0.5.1)
# Requirement already satisfied: SecretStorage<4.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (3.3.3)
# Requirement already satisfied: jsonpickle<5.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (4.0.5)
# Requirement already satisfied: contextlib2<22.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (21.6.0)
# Requirement already satisfied: docker<8.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (7.1.0)
# Requirement already satisfied: PyJWT<3.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (2.10.1)
# Requirement already satisfied: adal<=1.2.7,>=1.2.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (1.2.7)
# Requirement already satisfied: pyopenssl<25.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (24.3.0)
# Requirement already satisfied: jmespath<2.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-core~=1.59.0->azureml-sdk[automl]) (0.10.0)
# Requirement already satisfied: cryptography>=1.1.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from adal<=1.2.7,>=1.2.0->azureml-core~=1.59.0->azureml-sdk[automl]) (44.0.3)
# Requirement already satisfied: six>=1.11.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azure-core<2.0.0->azureml-core~=1.59.0->azureml-sdk[automl]) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azure-core<2.0.0->azureml-core~=1.59.0->azureml-sdk[automl]) (4.13.2)
# Requirement already satisfied: isodate<1.0.0,>=0.6.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azure-mgmt-authorization<5,>=0.40.0->azureml-core~=1.59.0->azureml-sdk[automl]) (0.7.2)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.3.2 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azure-mgmt-authorization<5,>=0.40.0->azureml-core~=1.59.0->azureml-sdk[automl]) (1.5.0)
# Requirement already satisfied: azureml-dataprep<5.2.0a,>=5.1.0a in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk[automl]) (5.1.6)
# Requirement already satisfied: pyarrow>=0.17.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk[automl]) (14.0.2)
# Requirement already satisfied: numpy!=1.19.3,<1.24 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk[automl]) (1.23.5)
# Requirement already satisfied: azureml-dataprep-native<42.0.0,>=41.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk[automl]) (41.0.0)
# Requirement already satisfied: azureml-dataprep-rslex~=2.22.2dev0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk[automl]) (2.22.5)
# Requirement already satisfied: cloudpickle<3.0.0,>=1.1.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk[automl]) (2.2.1)
# Requirement already satisfied: azure-identity>=1.7.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk[automl]) (1.22.0)
# Requirement already satisfied: jsonschema in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk[automl]) (4.23.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.1.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk[automl]) (6.0.2)
# Requirement already satisfied: fusepy<4.0.0,>=3.0.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk[automl]) (3.0.1)
# Requirement already satisfied: azureml-pipeline-core~=1.59.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-pipeline~=1.59.0->azureml-sdk[automl]) (1.59.0)
# Requirement already satisfied: azureml-pipeline-steps~=1.59.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-pipeline~=1.59.0->azureml-sdk[automl]) (1.59.0)
# Requirement already satisfied: azureml-automl-core~=1.59.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.59.0)
# Collecting azureml-automl-runtime~=1.59.0 (from azureml-train-automl~=1.59.0->azureml-sdk[automl])
#   Using cached azureml_automl_runtime-1.59.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting azureml-train-automl-runtime~=1.59.0 (from azureml-train-automl~=1.59.0->azureml-sdk[automl])
#   Using cached azureml_train_automl_runtime-1.59.0-py3-none-any.whl.metadata (3.2 kB)
# Collecting azureml-responsibleai~=1.59.0 (from azureml-train-automl~=1.59.0->azureml-sdk[automl])
#   Using cached azureml_responsibleai-1.59.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: azureml-telemetry~=1.59.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-core~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.59.0)
# Requirement already satisfied: importlib-metadata<=8.2.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-core~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (8.2.0)
# Requirement already satisfied: importlib-resources<=6.4.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-core~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (6.4.0)
# Collecting azureml-training-tabular~=1.59.0 (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl])
#   Using cached azureml_training_tabular-1.59.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: dill<0.4.0,>=0.2.8 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.3.9)
# Requirement already satisfied: gensim==4.3.2 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (4.3.2)
# Requirement already satisfied: smart-open==6.4.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (6.4.0)
# Collecting lightgbm<=3.2.1,>=3.0.0 (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl])
#   Using cached lightgbm-3.2.1-py3-none-manylinux1_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: pandas==1.5.3 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.5.3)
# Requirement already satisfied: psutil<5.9.4,>=5.2.2 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (5.9.3)
# Requirement already satisfied: scipy<=1.11.0,>=1.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.10.1)
# Requirement already satisfied: scikit-learn~=1.5.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.5.1)
# Requirement already satisfied: sklearn_pandas<=1.7.0,>=1.4.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.7.0)
# Requirement already satisfied: statsmodels<0.14,>=0.13.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.13.5)
# Requirement already satisfied: skl2onnx==1.15.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.15.0)
# Collecting onnxmltools==1.11.2 (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl])
#   Using cached onnxmltools-1.11.2-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: keras2onnx<=1.6.0,>=1.4.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.6.0)
# Requirement already satisfied: onnxconverter-common==1.13.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.13.0)
# Requirement already satisfied: onnx<=1.17.0,>=1.16.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.17.0)
# Requirement already satisfied: onnxruntime~=1.17.3 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.17.3)
# Requirement already satisfied: pmdarima==1.8.5 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.8.5)
# Requirement already satisfied: joblib==1.2.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.2.0)
# Requirement already satisfied: boto3<=1.20.19 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.20.19)
# Requirement already satisfied: botocore<=1.23.19 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.23.19)
# Requirement already satisfied: dataclasses<=0.8,>=0.6 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.6)
# Requirement already satisfied: arch<=5.6.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (5.6.0)
# Requirement already satisfied: dotnetcore2<4.0.0,>=3.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (3.1.23)
# Requirement already satisfied: protobuf in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from onnxconverter-common==1.13.0->azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (5.28.3)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from pmdarima==1.8.5->azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (3.1.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from pmdarima==1.8.5->azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (78.1.1)
# Requirement already satisfied: property-cached>=1.6.4 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from arch<=5.6.0->azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.6.4)
# Collecting azureml-interpret~=1.59.0 (from azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl])
#   Using cached azureml_interpret-1.59.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: fairlearn==0.7.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.7.0)
# Requirement already satisfied: responsibleai==0.36.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.36.0)
# Requirement already satisfied: dice-ml<0.12,>=0.11 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.11)
# Requirement already satisfied: econml>=0.14.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.15.1)
# Requirement already satisfied: erroranalysis>=0.5.4 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.5.5)
# Requirement already satisfied: interpret-community>=0.31.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.31.0)
# Requirement already satisfied: numba<=0.58.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.56.4)
# Requirement already satisfied: semver~=2.13.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (2.13.0)
# Requirement already satisfied: ml-wrappers in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.5.6)
# Requirement already satisfied: networkx<=2.5 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (2.5)
# Requirement already satisfied: raiutils>=0.4.2 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.4.2)
# Requirement already satisfied: ipykernel>=6.22.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (6.29.5)
# Requirement already satisfied: applicationinsights in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-telemetry~=1.59.0->azureml-automl-core~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.11.10)
# Requirement already satisfied: azure-storage-queue~=12.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (12.12.0)
# Requirement already satisfied: jinja2<4 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (3.1.6)
# Requirement already satisfied: dask<=2023.2.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from dask[complete]<=2023.2.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (2023.2.0)
# Requirement already satisfied: bokeh<3.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (2.4.3)
# Collecting azureml-mlflow~=1.59.0 (from azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl])
#   Using cached azureml_mlflow-1.59.0.post1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: mlflow-skinny in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (2.22.0)
# Requirement already satisfied: azure-storage-blob<=12.19.0,>=12.5.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (12.19.0)
# Requirement already satisfied: azureml-train-restclients-hyperdrive~=1.59.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from azureml-train-core~=1.59.0->azureml-sdk[automl]) (1.59.0)
# Requirement already satisfied: pillow>=7.1.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from bokeh<3.0.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (11.2.1)
# Requirement already satisfied: tornado>=5.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from bokeh<3.0.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (6.4.2)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from boto3<=1.20.19->azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.5.2)
# Requirement already satisfied: click>=7.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from dask<=2023.2.0->dask[complete]<=2023.2.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (8.1.8)
# Requirement already satisfied: fsspec>=0.6.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from dask<=2023.2.0->dask[complete]<=2023.2.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (2025.3.2)
# Requirement already satisfied: partd>=0.3.10 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from dask<=2023.2.0->dask[complete]<=2023.2.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.4.2)
# Requirement already satisfied: toolz>=0.8.2 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from dask<=2023.2.0->dask[complete]<=2023.2.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.0.0)
# Requirement already satisfied: distributed==2023.2.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from dask[complete]<=2023.2.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (2023.2.0)
# Requirement already satisfied: locket>=1.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from distributed==2023.2.0->dask[complete]<=2023.2.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from distributed==2023.2.0->dask[complete]<=2023.2.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.1.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from distributed==2023.2.0->dask[complete]<=2023.2.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from distributed==2023.2.0->dask[complete]<=2023.2.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (3.1.0)
# Requirement already satisfied: zict>=2.1.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from distributed==2023.2.0->dask[complete]<=2023.2.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (3.0.0)
# Requirement already satisfied: tqdm in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from dice-ml<0.12,>=0.11->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (4.67.1)
# Requirement already satisfied: distro>=1.2.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from dotnetcore2<4.0.0,>=3.0.0->azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.9.0)
# Requirement already satisfied: zipp>=0.5 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from importlib-metadata<=8.2.0->azureml-automl-core~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (3.21.0)
# Requirement already satisfied: shap<=0.44.0,>=0.20.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from interpret-community>=0.31.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.43.0)
# Requirement already satisfied: interpret-core<=0.5.0,>=0.1.20 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from interpret-community>=0.31.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from jinja2<4->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (3.0.2)
# Requirement already satisfied: fire in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from keras2onnx<=1.6.0,>=1.4.0->azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.7.0)
# Requirement already satisfied: pygments in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from knack<0.13.0->azureml-core~=1.59.0->azureml-sdk[automl]) (2.19.1)
# Requirement already satisfied: tabulate in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from knack<0.13.0->azureml-core~=1.59.0->azureml-sdk[automl]) (0.9.0)
# Requirement already satisfied: wheel in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from lightgbm<=3.2.1,>=3.0.0->azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.45.1)
# Requirement already satisfied: cffi>=1.12 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from cryptography>=1.1.0->adal<=1.2.7,>=1.2.0->azureml-core~=1.59.0->azureml-sdk[automl]) (1.17.1)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.59.0->azureml-sdk[automl]) (2025.4.26)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.59.0->azureml-sdk[automl]) (2.0.0)
# Requirement already satisfied: pyasn1>=0.1.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from ndg-httpsclient<=0.5.1->azureml-core~=1.59.0->azureml-sdk[automl]) (0.6.1)
# Requirement already satisfied: decorator>=4.3.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from networkx<=2.5->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (5.2.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from numba<=0.58.1->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.39.1)
# Requirement already satisfied: coloredlogs in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from onnxruntime~=1.17.3->azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (15.0.1)
# Requirement already satisfied: flatbuffers in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from onnxruntime~=1.17.3->azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (25.2.10)
# Requirement already satisfied: sympy in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from onnxruntime~=1.17.3->azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.14.0)
# Requirement already satisfied: bcrypt>=3.2 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from paramiko<4.0.0,>=2.0.8->azureml-core~=1.59.0->azureml-sdk[automl]) (4.3.0)
# Requirement already satisfied: pynacl>=1.5 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from paramiko<4.0.0,>=2.0.8->azureml-core~=1.59.0->azureml-sdk[automl]) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from requests<3.0.0,>=2.19.1->requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.59.0->azureml-sdk[automl]) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from requests<3.0.0,>=2.19.1->requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.59.0->azureml-sdk[automl]) (3.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.59.0->azureml-sdk[automl]) (1.7.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from scikit-learn~=1.5.1->azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (3.6.0)
# Requirement already satisfied: jeepney>=0.6 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from SecretStorage<4.0.0->azureml-core~=1.59.0->azureml-sdk[automl]) (0.9.0)
# Requirement already satisfied: slicer==0.0.7 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from shap<=0.44.0,>=0.20.0->interpret-community>=0.31.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.0.7)
# Requirement already satisfied: patsy>=0.5.2 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from statsmodels<0.14,>=0.13.0->azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.0.1)
# Requirement already satisfied: pycparser in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=1.1.0->adal<=1.2.7,>=1.2.0->azureml-core~=1.59.0->azureml-sdk[automl]) (2.22)
# Requirement already satisfied: sparse in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from econml>=0.14.1->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.15.5)
# Requirement already satisfied: comm>=0.1.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from ipykernel>=6.22.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from ipykernel>=6.22.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from ipykernel>=6.22.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (8.18.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from ipykernel>=6.22.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from ipykernel>=6.22.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from ipykernel>=6.22.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.1.7)
# Requirement already satisfied: nest-asyncio in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from ipykernel>=6.22.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from ipykernel>=6.22.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (26.4.0)
# Requirement already satisfied: traitlets>=5.4.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from ipykernel>=6.22.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (5.14.3)
# Requirement already satisfied: jedi>=0.16 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=6.22.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=6.22.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (3.0.51)
# Requirement already satisfied: stack-data in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=6.22.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.6.3)
# Requirement already satisfied: exceptiongroup in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=6.22.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=6.22.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (4.9.0)
# Requirement already satisfied: wcwidth in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.22.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.22.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.8.4)
# Requirement already satisfied: entrypoints in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=6.22.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.22.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (4.3.8)
# Requirement already satisfied: ptyprocess>=0.5 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=6.22.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.7.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from requests-oauthlib>=0.5.0->msrest<=0.7.1,>=0.5.1->azureml-core~=1.59.0->azureml-sdk[automl]) (3.2.2)
# Requirement already satisfied: backports.weakref in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from backports.tempfile->azureml-core~=1.59.0->azureml-sdk[automl]) (1.0.post1)
# Requirement already satisfied: termcolor in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from fire->keras2onnx<=1.6.0,>=1.4.0->azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (3.1.0)
# Requirement already satisfied: attrs>=22.2.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk[automl]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk[automl]) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk[automl]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime~=1.59.0->azureml-dataset-runtime[fuse]~=1.59.0->azureml-sdk[automl]) (0.24.0)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (5.5.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.52.0)
# Requirement already satisfied: fastapi<1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.115.12)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (3.1.44)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.32.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.32.1)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (2.11.4)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.5.3)
# Requirement already satisfied: uvicorn<1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.34.2)
# Requirement already satisfied: google-auth~=2.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (2.40.1)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from fastapi<1->mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.46.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (4.9.1)
# Requirement already satisfied: deprecated>=1.2.6 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.53b1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.53b1)
# Requirement already satisfied: annotated-types>=0.6.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.4.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.3.1)
# Requirement already satisfied: h11>=0.8 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from uvicorn<1->mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny->azureml-mlflow~=1.59.0->azureml-train-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.17.2)
# Requirement already satisfied: executing>=1.2.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.22.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.22.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (3.0.0)
# Requirement already satisfied: pure-eval in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.22.0->responsibleai==0.36.0->azureml-responsibleai~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from sympy->onnxruntime~=1.17.3->azureml-automl-runtime~=1.59.0->azureml-train-automl~=1.59.0->azureml-sdk[automl]) (1.3.0)
# Using cached azureml_train_automl-1.59.0-py3-none-any.whl (2.4 kB)
# Using cached azureml_automl_runtime-1.59.0-py3-none-any.whl (1.8 MB)
# Using cached onnxmltools-1.11.2-py2.py3-none-any.whl (322 kB)
# Using cached azureml_responsibleai-1.59.0-py3-none-any.whl (99 kB)
# Using cached azureml_interpret-1.59.0-py3-none-any.whl (52 kB)
# Using cached azureml_train_automl_runtime-1.59.0-py3-none-any.whl (420 kB)
# Using cached azureml_mlflow-1.59.0.post1-py3-none-any.whl (1.0 MB)
# Using cached azureml_training_tabular-1.59.0-py3-none-any.whl (1.7 MB)
# Using cached lightgbm-3.2.1-py3-none-manylinux1_x86_64.whl (2.0 MB)
# Installing collected packages: lightgbm, onnxmltools, azureml-mlflow, azureml-interpret, azureml-responsibleai, azureml-training-tabular, azureml-automl-runtime, azureml-train-automl-runtime, azureml-train-automl
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 4.6.0
#     Uninstalling lightgbm-4.6.0:
#       Successfully uninstalled lightgbm-4.6.0
#   Attempting uninstall: onnxmltools━━━━━━━━━━━━━ 0/9 [lightgbm]
#     Found existing installation: onnxmltools 1.12.032m0/9 [lightgbm]
#     Uninstalling onnxmltools-1.12.0:━━━━━━━━ 0/9 [lightgbm]
#       Successfully uninstalled onnxmltools-1.12.00/9 [lightgbm]
#   Attempting uninstall: azureml-mlflow━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/9 [onnxmltools]
#     Found existing installation: azureml-mlflow 1.60.0.post1━━ 1/9 [onnxmltools]
#     Uninstalling azureml-mlflow-1.60.0.post1:━━━━━━━━━━━━━━━━━ 1/9 [onnxmltools]
#       Successfully uninstalled azureml-mlflow-1.60.0.post1━━━━ 1/9 [onnxmltools]
#   Attempting uninstall: azureml-interpret━━━━━━━━━━━━━━━━━━━━━━━━━ 2/9 [azureml-mlflow]
#     Found existing installation: azureml-interpret 1.60.0━━━━━ 2/9 [azureml-mlflow]
#     Uninstalling azureml-interpret-1.60.0:━━━━━━━━━━━━━━━━━━━━ 2/9 [azureml-mlflow]
#       Successfully uninstalled azureml-interpret-1.60.0━━━━━━━ 2/9 [azureml-mlflow]
#   Attempting uninstall: azureml-responsibleai━━━━━━━━━━━━━━━━━━━━━ 3/9 [azureml-interpret]
#     Found existing installation: azureml-responsibleai 1.60.0━ 3/9 [azureml-interpret]
#     Uninstalling azureml-responsibleai-1.60.0:━━━━━━━━━━━━━━━━ 3/9 [azureml-interpret]
#       Successfully uninstalled azureml-responsibleai-1.60.0━━━ 3/9 [azureml-interpret]
#   Attempting uninstall: azureml-training-tabular━━━━━━━━━━━━━━━━━━ 4/9 [azureml-responsibleai]
#     Found existing installation: azureml-training-tabular 1.60.00m 4/9 [azureml-responsibleai]
#     Uninstalling azureml-training-tabular-1.60.0:━━━━━━━━━━━━━ 4/9 [azureml-responsibleai]
#       Successfully uninstalled azureml-training-tabular-1.60.0 4/9 [azureml-responsibleai]
#   Attempting uninstall: azureml-automl-runtime90m━━━━━━━━━━━━━━━━━ 5/9 [azureml-training-tabular]
#     Found existing installation: azureml-automl-runtime 1.60.0 5/9 [azureml-training-tabular]
#     Uninstalling azureml-automl-runtime-1.60.0:━━━━━━━━━━━━━━━ 5/9 [azureml-training-tabular]
#       Successfully uninstalled azureml-automl-runtime-1.60.0━━━━━━ 6/9 [azureml-automl-runtime]
#   Attempting uninstall: azureml-train-automl-runtimem━━━━━━━━━━━━━ 6/9 [azureml-automl-runtime]
#     Found existing installation: azureml-train-automl-runtime 1.60.06/9 [azureml-automl-runtime]
#     Uninstalling azureml-train-automl-runtime-1.60.0:━━━━━━━━ 7/9 [azureml-train-automl-runtime]
#       Successfully uninstalled azureml-train-automl-runtime-1.60.0 7/9 [azureml-train-automl-runtime]
#   Attempting uninstall: azureml-train-automl╺━━━━━━━━ 7/9 [azureml-train-automl-runtime]
#     Found existing installation: azureml-train-automl 1.60.0━━ 7/9 [azureml-train-automl-runtime]
#     Uninstalling azureml-train-automl-1.60.0:━━━━━━━━ 7/9 [azureml-train-automl-runtime]
#       Successfully uninstalled azureml-train-automl-1.60.0━━━━ 7/9 [azureml-train-automl-runtime]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [azureml-train-automl]-train-automl-runtime]
# Successfully installed azureml-automl-runtime-1.59.0 azureml-interpret-1.59.0 azureml-mlflow-1.59.0.post1 azureml-responsibleai-1.59.0 azureml-train-automl-1.59.0 azureml-train-automl-runtime-1.59.0 azureml-training-tabular-1.59.0 lightgbm-3.2.1 onnxmltools-1.11.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /anaconda/envs/automl-env3/lib/python3.9/site-packages (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.60.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-280430
# aml-quickstarts-280430
# westus2
# 976ee174-3882-4721-b90a-b5fef6b72f24

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'proj2ml'
project_folder = '.'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: proj2ml,
# Workspace: quick-starts-ws-280430)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "CluserML"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "BankMarketing Dataset"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
# {'infer_column_types': 'False', 'activity': 'to_pandas_dataframe'}
# {'infer_column_types': 'False', 'activity': 'to_pandas_dataframe', 'activityApp': 'TabularDataset'}
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
# {'infer_column_types': 'False', 'activity': 'to_pandas_dataframe'}
# {'infer_column_types': 'False', 'activity': 'to_pandas_dataframe', 'activityApp': 'TabularDataset'}
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [c9b4d94c][e915a395-a396-452f-b67e-078574de3c4f], (This step will run and generate new outputs)
# Submitted PipelineRun ef9b0b0a-aaa3-4a74-9e0b-776f79070be2
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/ef9b0b0a-aaa3-4a74-9e0b-776f79070be2?wsid=/subscriptions/976ee174-3882-4721-b90a-b5fef6b72f24/resourcegroups/aml-quickstarts-280430/workspaces/quick-starts-ws-280430&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254

# %%
pip install azure-sdk
# Out:
# ERROR: Could not find a version that satisfies the requirement azure-sdk (from versions: none)
# ERROR: No matching distribution found for azure-sdk
# Note: you may need to restart the kernel to use updated packages.

# %%
from collections.abc import Mapping
from azureml.widgets import RunDetails

RunDetails(pipeline_run).show()
# Out:
# Add type hints to the `predict` method to enable data validation and automatic signature inference during model logging. Check https://mlflow.org/docs/latest/model/python_model.html#type-hint-usage-in-pythonmodel for more details.
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# ERROR:azureml.data._dataset_client:[NOT_SUPPORTED_API_USE_ATTEMPT] The [_DatasetClient.get] API has been deprecated and is no longer supported
# ERROR:azureml.data._dataset_client:[NOT_SUPPORTED_API_USE_ATTEMPT] The [_DatasetClient.get] API has been deprecated and is no longer supported
# ERROR:azureml.data._dataset_client:[NOT_SUPPORTED_API_USE_ATTEMPT] The [_DatasetClient.get] API has been deprecated and is no longer supported
# ERROR:azureml.data._dataset_client:[NOT_SUPPORTED_API_USE_ATTEMPT] The [_DatasetClient.get] API has been deprecated and is no longer supported

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: ef9b0b0a-aaa3-4a74-9e0b-776f79070be2
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/ef9b0b0a-aaa3-4a74-9e0b-776f79070be2?wsid=/subscriptions/976ee174-3882-4721-b90a-b5fef6b72f24/resourcegroups/aml-quickstarts-280430/workspaces/quick-starts-ws-280430&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254
# PipelineRun Status: Running
#
#
# StepRunId: a1260661-f32d-4b9f-9ced-4c0482edcf5e
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/a1260661-f32d-4b9f-9ced-4c0482edcf5e?wsid=/subscriptions/976ee174-3882-4721-b90a-b5fef6b72f24/resourcegroups/aml-quickstarts-280430/workspaces/quick-starts-ws-280430&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254
# StepRun( automl_module ) Status: NotStarted
# StepRun( automl_module ) Status: Running
#
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
#
# Warnings:
# No scores improved over last 10 iterations, so experiment stopped early. This early stopping behavior can be disabled by setting enable_early_stopping = False in AutoMLConfig for notebook/python SDK runs.
# {'runId': 'a1260661-f32d-4b9f-9ced-4c0482edcf5e', 'target': 'CluserML', 'status': 'Completed', 'startTimeUtc': '2025-05-09T14:16:52.483878Z', 'endTimeUtc': '2025-05-09T14:29:13.106066Z', 'services': {}, 'warnings': [{'source': 'JasmineService', 'message': 'No scores improved over last 10 iterations, so experiment stopped early. This early stopping behavior can be disabled by setting enable_early_stopping = False in AutoMLConfig for notebook/python SDK runs.'}], 'properties': {'ContentSnapshotId': 'db92a37d-8f70-4ea4-969c-fdf7eeae8983', 'StepType': 'AutoMLStep', 'azureml.moduleid': 'e915a395-a396-452f-b67e-078574de3c4f', 'azureml.moduleFamilyId': 'f85a31a7-5740-4e79-b347-ea937aa49758', 'azureml.moduleName': 'automl_module', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'c9b4d94c', 'azureml.pipelinerunid': 'ef9b0b0a-aaa3-4a74-9e0b-776f79070be2', 'azureml.pipeline': 'ef9b0b0a-aaa3-4a74-9e0b-776f79070be2', 'azureml.rootpipelinerunid': 'ef9b0b0a-aaa3-4a74-9e0b-776f79070be2', 'azureml.pipelineComponent': 'masterautomlcloud', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'AUC_weighted', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': '', 'target': 'CluserML', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "976ee174-3882-4721-b90a-b5fef6b72f24", "resource_group": "aml-quickstarts-280430", "workspace_name": "quick-starts-ws-280430", "region": "westus2", "compute_target": "CluserML", "spark_service": null, "azure_service": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "enable_batch_run": false, "enable_parallel_run": false, "num_procs": null, "enable_run_restructure": false, "start_auxiliary_runs_before_parent_complete": false, "enable_code_generation": true, "force_curated_environment": false, "iterations": 1000, "primary_metric": "AUC_weighted", "task_type": "classification", "positive_label": null, "data_script": null, "test_size": 0.0, "test_include_predictions_only": false, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 5, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 20, "experiment_exit_score": null, "partition_column_names": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["DecisionTree", "SVM", "TensorFlowLinearClassifier", "LinearSVM", "LogisticRegression", "LightGBM", "GradientBoosting", "AveragedPerceptronClassifier", "TensorFlowDNN", "TabnetClassifier", "ExtremeRandomTrees", "RandomForest", "SGD", "KNN", "XGBoostClassifier", "BernoulliNaiveBayes", "MultinomialNaiveBayes"], "private_models": [], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_D2_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "scenario": "AutoML", "environment_label": null, "save_mlflow": false, "enable_categorical_indicators": false, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "arguments": null, "dataset_id": null, "hyperdrive_config": null, "validation_dataset_id": null, "run_source": null, "metrics": null, "enable_metric_confidence": false, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enab ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'ef9b0b0a-aaa3-4a74-9e0b-776f79070be2', 'status': 'Completed', 'startTimeUtc': '2025-05-09T14:16:37.682186Z', 'endTimeUtc': '2025-05-09T14:29:46.967574Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}', 'azureml.continue_on_step_failure': 'False', 'azureml.continue_on_failed_optional_input': 'True', 'azureml.pipelineComponent': 'pipelinerun', 'azureml.pipelines.stages': '{"Initialization":null,"Execution":{"StartTime":"2025-05-09T14:16:37.9553174+00:00","EndTime":"2025-05-09T14:29:46.8364575+00:00","Status":"Finished"}}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg280430.blob.core.windows.net/azureml/ExperimentRun/dcid.ef9b0b0a-aaa3-4a74-9e0b-776f79070be2/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=ll2hlKDZS1NrXFVQfeX8FtpZMo6%2BYKQODv51kwIE9AQ%3D&skoid=37b125c4-f4e2-4235-befb-d72cec942ada&sktid=660b3398-b80e-49d2-bc5b-ac1dc93b5254&skt=2025-05-09T13%3A15%3A53Z&ske=2025-05-11T13%3A25%3A53Z&sks=b&skv=2019-07-07&st=2025-05-09T14%3A19%3A48Z&se=2025-05-09T22%3A29%3A48Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg280430.blob.core.windows.net/azureml/ExperimentRun/dcid.ef9b0b0a-aaa3-4a74-9e0b-776f79070be2/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=vtgxjbR1jG5m1XHDVYdR2nLdYoTkHuula7XnS8qm79o%3D&skoid=37b125c4-f4e2-4235-befb-d72cec942ada&sktid=660b3398-b80e-49d2-bc5b-ac1dc93b5254&skt=2025-05-09T13%3A15%3A53Z&ske=2025-05-11T13%3A25%3A53Z&sks=b&skv=2019-07-07&st=2025-05-09T14%3A19%3A48Z&se=2025-05-09T22%3A29%3A48Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg280430.blob.core.windows.net/azureml/ExperimentRun/dcid.ef9b0b0a-aaa3-4a74-9e0b-776f79070be2/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=W37MWi7I9wMuTx0hKpms0Mkt3bn3VHXxhUzCniNE5hM%3D&skoid=37b125c4-f4e2-4235-befb-d72cec942ada&sktid=660b3398-b80e-49d2-bc5b-ac1dc93b5254&skt=2025-05-09T13%3A15%3A53Z&ske=2025-05-11T13%3A25%3A53Z&sks=b&skv=2019-07-07&st=2025-05-09T14%3A19%3A48Z&se=2025-05-09T22%3A29%3A48Z&sp=r'}, 'submittedBy': 'ODL_User 280430'}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/a1260661-f32d-4b9f-9ced-4c0482edcf5e/metrics_data
# Downloaded azureml/a1260661-f32d-4b9f-9ced-4c0482edcf5e/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  a1260661-f32d-4b9f-9ced-4c0482edcf5e_19  \
# matthews_correlation                                               [0.0]
# weighted_accuracy                                   [0.9843450583187134]
# precision_score_macro                               [0.4440060698027314]
# average_precision_score_micro                       [0.9588032405402586]
# recall_score_weighted                               [0.8880121396054628]
# balanced_accuracy                                                  [0.5]
# recall_score_macro                                                 [0.5]
# f1_score_weighted                                   [0.8353395018439429]
# average_precision_score_weighted                     [0.921441280417884]
# norm_macro_recall                                                  [0.0]
# AUC_micro                                           [0.9587018543293397]
# log_loss                                            [0.2844519628847007]
# recall_score_micro                                  [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# AUC_macro                                           [0.8554155158776469]
# f1_score_macro                                      [0.4703423886834914]
# accuracy                                            [0.8880121396054628]
# precision_score_weighted                             [0.788565560086672]
# precision_score_micro                               [0.8880121396054628]
# AUC_weighted                                        [0.8554155158776469]
# average_precision_score_macro                       [0.7266682411242182]
#
#                                  a1260661-f32d-4b9f-9ced-4c0482edcf5e_9  \
# matthews_correlation                               [0.3291159082160961]
# weighted_accuracy                                  [0.7340734040751529]
# precision_score_macro                              [0.6111736049638861]
# average_precision_score_micro                      [0.8381328901693756]
# recall_score_weighted                              [0.7359635811836115]
# balanced_accuracy                                  [0.7435768838207862]
# recall_score_macro                                 [0.7435768838207862]
# f1_score_weighted                                  [0.7820694079528548]
# average_precision_score_weighted                   [0.9236451424228547]
# norm_macro_recall                                  [0.4871537676415725]
# AUC_micro                                          [0.8402622265307486]
# log_loss                                           [0.5965698773956144]
# recall_score_micro                                 [0.7359635811836115]
# f1_score_micro                                     [0.7359635811836115]
# AUC_macro                                          [0.8632858013474187]
# f1_score_macro                                     [0.6107138860793735]
# accuracy                                           [0.7359635811836115]
# precision_score_weighted                           [0.8813581682101504]
# precision_score_micro                              [0.7359635811836115]
# AUC_weighted                                       [0.8632858013474187]
# average_precision_score_macro                      [0.7268295626662257]
#
#                                  a1260661-f32d-4b9f-9ced-4c0482edcf5e_11  \
# matthews_correlation                               [0.34019858801321295]
# weighted_accuracy                                   [0.7648931543130624]
# precision_score_macro                               [0.6183076858282937]
# average_precision_score_micro                       [0.8071859516776101]
# recall_score_weighted                               [0.7608497723823976]
# balanced_accuracy                                   [0.7445637375034038]
# recall_score_macro                                  [0.7445637375034038]
# f1_score_weighted                                   [0.8004168075957608]
# average_precision_score_weighted                    [0.9147935280514589]
# norm_macro_recall                                  [0.48912747500680753]
# AUC_micro                                           [0.8357255325468993]
# log_loss                                            [0.5555744865458587]
# recall_score_micro                                  [0.7608497723823976]
# f1_score_micro                                      [0.7608497723823976]
# AUC_macro                                           [0.8307955772654103]
# f1_score_macro                                      [0.6271755249920451]
# accuracy                                            [0.7608497723823976]
# precision_score_weighted                            [0.8807123764826089]
# precision_score_micro                               [0.7608497723823976]
# AUC_weighted                                        [0.8307955772654103]
# average_precision_score_macro                       [0.7183175166652511]
#
#                                  a1260661-f32d-4b9f-9ced-4c0482edcf5e_12  \
# matthews_correlation                                [0.5231250045786537]
# weighted_accuracy                                   [0.9588464085130249]
# precision_score_macro                                [0.794377847854753]
# average_precision_score_micro                       [0.9796736019290664]
# recall_score_weighted                               [0.9138088012139606]
# balanced_accuracy                                   [0.7324051999918495]
# recall_score_macro                                  [0.7324051999918495]
# f1_score_weighted                                   [0.9087485655110661]
# average_precision_score_weighted                    [0.9523114199391449]
# norm_macro_recall                                    [0.464810399983699]
# AUC_micro                                           [0.9786896502494928]
# log_loss                                           [0.21143958424122453]
# recall_score_micro                                  [0.9138088012139606]
# f1_score_micro                                      [0.9138088012139606]
# AUC_macro                                           [0.9405160165750666]
# f1_score_macro                                      [0.7582948132750074]
# accuracy                                            [0.9138088012139606]
# precision_score_weighted                             [0.906281456407151]
# precision_score_micro                               [0.9138088012139606]
# AUC_weighted                                        [0.9405160165750666]
# average_precision_score_macro                       [0.8136182410340502]
#
#                                  a1260661-f32d-4b9f-9ced-4c0482edcf5e_14  \
# matthews_correlation                               [0.48055365822535684]
# weighted_accuracy                                   [0.9627471231554042]
# precision_score_macro                                [0.791017562165937]
# average_precision_score_micro                        [0.977588151624343]
# recall_score_weighted                               [0.9101669195751139]
# balanced_accuracy                                   [0.6983830603856278]
# recall_score_macro                                  [0.6983830603856278]
# f1_score_weighted                                   [0.9017032337698546]
# average_precision_score_weighted                    [0.9515694973462892]
# norm_macro_recall                                   [0.3967661207712556]
# AUC_micro                                           [0.9777873772971878]
# log_loss                                           [0.20742489746148812]
# recall_score_micro                                  [0.9101669195751139]
# f1_score_micro                                      [0.9101669195751139]
# AUC_macro                                           [0.9344328115188192]
# f1_score_macro                                      [0.7326278853007293]
# accuracy                                            [0.9101669195751139]
# precision_score_weighted                            [0.8993236079872186]
# precision_score_micro                               [0.9101669195751139]
# AUC_weighted                                        [0.9344328115188193]
# average_precision_score_macro                       [0.8174362336952881]
#
#                                  a1260661-f32d-4b9f-9ced-4c0482edcf5e_17  \
# matthews_correlation                                [0.4745027040822183]
# weighted_accuracy                                   [0.7907360355462064]
# precision_score_macro                               [0.6653758020371225]
# average_precision_score_micro                       [0.8906956952653077]
# recall_score_weighted                               [0.8006069802731411]
# balanced_accuracy                                    [0.840365418350014]
# recall_score_macro                                   [0.840365418350014]
# f1_score_weighted                                   [0.8334469491797993]
# average_precision_score_weighted                    [0.9397367901590755]
# norm_macro_recall                                    [0.680730836700028]
# AUC_micro                                           [0.8933152498036985]
# log_loss                                            [0.4203310080774633]
# recall_score_micro                                  [0.8006069802731411]
# f1_score_micro                                      [0.8006069802731411]
# AUC_macro                                           [0.9122769970010021]
# f1_score_macro                                      [0.6879152325518534]
# accuracy                                            [0.8006069802731411]
# precision_score_weighted                            [0.9118377569547986]
# precision_score_micro                               [0.8006069802731411]
# AUC_weighted                                        [0.9122769970010022]
# average_precision_score_macro                        [0.770846993595558]
#
#                                  a1260661-f32d-4b9f-9ced-4c0482edcf5e_15  \
# matthews_correlation                               [0.39340196123415067]
# weighted_accuracy                                   [0.9805076942162568]
# precision_score_macro                               [0.8515415609080743]
# average_precision_score_micro                       [0.9786283276460308]
# recall_score_weighted                               [0.9068285280728376]
# balanced_accuracy                                   [0.6100617397151414]
# recall_score_macro                                  [0.6100617397151414]
# f1_score_weighted                                   [0.8830383472854728]
# average_precision_score_weighted                    [0.9536793029588512]
# norm_macro_recall                                  [0.22012347943028288]
# AUC_micro                                           [0.9775185191155036]
# log_loss                                           [0.21258977849913452]
# recall_score_micro                                  [0.9068285280728376]
# f1_score_micro                                      [0.9068285280728376]
# AUC_macro                                           [0.9439716252938333]
# f1_score_macro                                      [0.6517398975771399]
# accuracy                                            [0.9068285280728376]
# precision_score_weighted                            [0.8973958505740813]
# precision_score_micro                               [0.9068285280728376]
# AUC_weighted                                        [0.9439716252938334]
# average_precision_score_macro                       [0.8180629123186702]
#
#                                  a1260661-f32d-4b9f-9ced-4c0482edcf5e_16  \
# matthews_correlation                                [0.5238288494614208]
# weighted_accuracy                                   [0.8411526027126678]
# precision_score_macro                               [0.6937974944145098]
# average_precision_score_micro                       [0.8847988203557676]
# recall_score_weighted                               [0.8437025796661608]
# balanced_accuracy                                   [0.8539734406229913]
# recall_score_macro                                  [0.8539734406229913]
# f1_score_weighted                                   [0.8659213543958487]
# average_precision_score_weighted                    [0.9364343982049801]
# norm_macro_recall                                   [0.7079468812459826]
# AUC_micro                                           [0.9107817288806096]
# log_loss                                           [0.40290230966751145]
# recall_score_micro                                  [0.8437025796661608]
# f1_score_micro                                      [0.8437025796661608]
# AUC_macro                                           [0.9229976271054576]
# f1_score_macro                                      [0.7296781721804722]
# accuracy                                            [0.8437025796661608]
# precision_score_weighted                            [0.9162625570891886]
# precision_score_micro                               [0.8437025796661608]
# AUC_weighted                                        [0.9229976271054576]
# average_precision_score_macro                       [0.7552890953024709]
#
#                                  a1260661-f32d-4b9f-9ced-4c0482edcf5e_20  \
# matthews_correlation                               [0.41778310629483134]
# weighted_accuracy                                   [0.9607196759303707]
# precision_score_macro                               [0.7638987435328899]
# average_precision_score_micro                       [0.9671420339074859]
# recall_score_weighted                               [0.9019726858877086]
# balanced_accuracy                                   [0.6653500899328884]
# recall_score_macro                                  [0.6653500899328884]
# f1_score_weighted                                   [0.8907906149634255]
# average_precision_score_weighted                    [0.9383199084098308]
# norm_macro_recall                                   [0.3307001798657767]
# AUC_micro                                           [0.9696798156032616]
# log_loss                                           [0.22630538933197097]
# recall_score_micro                                  [0.9019726858877086]
# f1_score_micro                                      [0.9019726858877086]
# AUC_macro                                           [0.9207719965101223]
# f1_score_macro                                      [0.6988942703097871]
# accuracy                                            [0.9019726858877086]
# precision_score_weighted                            [0.8875607647592548]
# precision_score_micro                               [0.9019726858877086]
# AUC_weighted                                        [0.9207719965101224]
# average_precision_score_macro                       [0.7616028543784663]
#
#                                  a1260661-f32d-4b9f-9ced-4c0482edcf5e_18  ...  \
# matthews_correlation                                [0.5328108142609521]  ...
# weighted_accuracy                                   [0.9546457273395061]  ...
# precision_score_macro                               [0.7881835838009958]  ...
# average_precision_score_micro                       [0.9797798706773968]  ...
# recall_score_weighted                               [0.9132018209408195]  ...
# balanced_accuracy                                   [0.7462730180958679]  ...
# recall_score_macro                                  [0.7462730180958679]  ...
# f1_score_weighted                                   [0.9098016443897835]  ...
# average_precision_score_weighted                    [0.9519080952569361]  ...
# norm_macro_recall                                  [0.49254603619173576]  ...
# AUC_micro                                            [0.978789217119791]  ...
# log_loss                                           [0.19693610296079414]  ...
# recall_score_micro                                  [0.9132018209408195]  ...
# f1_score_micro                                      [0.9132018209408195]  ...
# AUC_macro                                           [0.9415278773430249]  ...
# f1_score_macro                                      [0.7648974537064757]  ...
# accuracy                                            [0.9132018209408195]  ...
# precision_score_weighted                             [0.907597716175493]  ...
# precision_score_micro                               [0.9132018209408195]  ...
# AUC_weighted                                        [0.9415278773430249]  ...
# average_precision_score_macro                       [0.8112595115150514]  ...
#
#                                  a1260661-f32d-4b9f-9ced-4c0482edcf5e_33  \
# matthews_correlation                               [0.47847436072253124]
# weighted_accuracy                                   [0.9539215076462723]
# precision_score_macro                               [0.7692516154463418]
# average_precision_score_micro                       [0.9780978067836411]
# recall_score_weighted                               [0.9059180576631259]
# balanced_accuracy                                   [0.7125685610923095]
# recall_score_macro                                  [0.7125685610923095]
# f1_score_weighted                                   [0.9003945609451778]
# average_precision_score_weighted                    [0.9482474801208366]
# norm_macro_recall                                  [0.42513712218461897]
# AUC_micro                                           [0.9770006055986793]
# log_loss                                           [0.19353624173211753]
# recall_score_micro                                  [0.9059180576631259]
# f1_score_micro                                      [0.9059180576631259]
# AUC_macro                                           [0.9360823529629692]
# f1_score_macro                                      [0.7361668736452545]
# accuracy                                            [0.9059180576631259]
# precision_score_weighted                            [0.8973044160136986]
# precision_score_micro                               [0.9059180576631259]
# AUC_weighted                                         [0.936082352962969]
# average_precision_score_macro                       [0.7973949197161567]
#
#                                  a1260661-f32d-4b9f-9ced-4c0482edcf5e_39  \
# matthews_correlation                                [0.5169403854722023]
# weighted_accuracy                                   [0.9599799347799869]
# precision_score_macro                               [0.7951957948859203]
# average_precision_score_micro                       [0.9811440911892908]
# recall_score_weighted                                 [0.91350531107739]
# balanced_accuracy                                   [0.7263136592404885]
# recall_score_macro                                  [0.7263136592404885]
# f1_score_weighted                                   [0.9078065866719532]
# average_precision_score_weighted                    [0.9549578117270506]
# norm_macro_recall                                  [0.45262731848097704]
# AUC_micro                                           [0.9802333512172994]
# log_loss                                           [0.19819253010825402]
# recall_score_micro                                    [0.91350531107739]
# f1_score_micro                                        [0.91350531107739]
# AUC_macro                                           [0.9462412498356016]
# f1_score_macro                                      [0.7544209203066695]
# accuracy                                              [0.91350531107739]
# precision_score_weighted                            [0.9053222720980019]
# precision_score_micro                                 [0.91350531107739]
# AUC_weighted                                        [0.9462412498356018]
# average_precision_score_macro                       [0.8226752199454861]
#
#                                  a1260661-f32d-4b9f-9ced-4c0482edcf5e_38  \
# matthews_correlation                                [0.4677782154586793]
# weighted_accuracy                                   [0.9671993669085064]
# precision_score_macro                               [0.8006115398503051]
# average_precision_score_micro                        [0.980835738875089]
# recall_score_weighted                               [0.9104704097116844]
# balanced_accuracy                                   [0.6819760969311675]
# recall_score_macro                                  [0.6819760969311675]
# f1_score_weighted                                   [0.8995434898898478]
# average_precision_score_weighted                    [0.9552616483762372]
# norm_macro_recall                                   [0.3639521938623349]
# AUC_micro                                           [0.9799063739836649]
# log_loss                                           [0.21846545822103466]
# recall_score_micro                                  [0.9104704097116844]
# f1_score_micro                                      [0.9104704097116844]
# AUC_macro                                           [0.9465042873258536]
# f1_score_macro                                      [0.7215808530463055]
# accuracy                                            [0.9104704097116844]
# precision_score_weighted                            [0.8984551937115196]
# precision_score_micro                               [0.9104704097116844]
# AUC_weighted                                        [0.9465042873258537]
# average_precision_score_macro                       [0.8239552642596301]
#
#                                  a1260661-f32d-4b9f-9ced-4c0482edcf5e_34  \
# matthews_correlation                                               [0.0]
# weighted_accuracy                                   [0.9843450583187134]
# precision_score_macro                               [0.4440060698027314]
# average_precision_score_micro                       [0.9417101717025174]
# recall_score_weighted                               [0.8880121396054628]
# balanced_accuracy                                                  [0.5]
# recall_score_macro                                                 [0.5]
# f1_score_weighted                                   [0.8353395018439429]
# average_precision_score_weighted                    [0.8988201444430816]
# norm_macro_recall                                                  [0.0]
# AUC_micro                                           [0.9551005915524741]
# log_loss                                            [0.6770810969201694]
# recall_score_micro                                  [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# AUC_macro                                            [0.837308996808355]
# f1_score_macro                                      [0.4703423886834914]
# accuracy                                            [0.8880121396054628]
# precision_score_weighted                             [0.788565560086672]
# precision_score_micro                               [0.8880121396054628]
# AUC_weighted                                         [0.837308996808355]
# average_precision_score_macro                        [0.673316404215818]
#
#                                  a1260661-f32d-4b9f-9ced-4c0482edcf5e_27  \
# matthews_correlation                               [0.47422181829067633]
# weighted_accuracy                                   [0.9616954582031879]
# precision_score_macro                               [0.7860925036001488]
# average_precision_score_micro                       [0.9773540307790931]
# recall_score_weighted                               [0.9089529590288316]
# balanced_accuracy                                   [0.6965154015860049]
# recall_score_macro                                  [0.6965154015860049]
# f1_score_weighted                                    [0.900539981658476]
# average_precision_score_weighted                      [0.94835501196234]
# norm_macro_recall                                   [0.3930308031720098]
# AUC_micro                                           [0.9762675318514971]
# log_loss                                           [0.19873978109892296]
# recall_score_micro                                  [0.9089529590288316]
# f1_score_micro                                      [0.9089529590288316]
# AUC_macro                                           [0.9310008206028745]
# f1_score_macro                                       [0.729809956769593]
# accuracy                                            [0.9089529590288316]
# precision_score_weighted                            [0.8979309459394659]
# precision_score_micro                               [0.9089529590288316]
# AUC_weighted                                        [0.9310008206028745]
# average_precision_score_macro                       [0.8006298573247423]
#
#                                  a1260661-f32d-4b9f-9ced-4c0482edcf5e_1  \
# matthews_correlation                                 [0.52924365161229]
# weighted_accuracy                                   [0.952375685487909]
# precision_score_macro                              [0.7826005666081467]
# average_precision_score_micro                      [0.9793987356897456]
# recall_score_weighted                              [0.9116843702579667]
# balanced_accuracy                                  [0.7477868729473351]
# recall_score_macro                                 [0.7477868729473351]
# f1_score_weighted                                  [0.9087877883554606]
# average_precision_score_weighted                    [0.950146970738567]
# norm_macro_recall                                  [0.4955737458946703]
# AUC_micro                                          [0.9783641467160662]
# log_loss                                          [0.18692041784468305]
# recall_score_micro                                 [0.9116843702579667]
# f1_score_micro                                     [0.9116843702579667]
# AUC_macro                                           [0.942328104073932]
# f1_score_macro                                      [0.763561123165114]
# accuracy                                           [0.9116843702579667]
# precision_score_weighted                           [0.9067326786550023]
# precision_score_micro                              [0.9116843702579667]
# AUC_weighted                                        [0.942328104073932]
# average_precision_score_macro                      [0.8028233128807174]
#
#                                  a1260661-f32d-4b9f-9ced-4c0482edcf5e_3  \
# matthews_correlation                              [0.10287827656329485]
# weighted_accuracy                                  [0.9836327958961727]
# precision_score_macro                              [0.7949010654490106]
# average_precision_score_micro                      [0.9687947687240641]
# recall_score_weighted                              [0.8892261001517451]
# balanced_accuracy                                  [0.5089724496014612]
# recall_score_macro                                 [0.5089724496014612]
# f1_score_weighted                                  [0.8399633475782208]
# average_precision_score_weighted                   [0.9339346279902265]
# norm_macro_recall                                [0.017944899202922304]
# AUC_micro                                          [0.9682084180519066]
# log_loss                                             [0.25575051532408]
# recall_score_micro                                 [0.8892261001517451]
# f1_score_micro                                     [0.8892261001517451]
# AUC_macro                                           [0.903152652510804]
# f1_score_macro                                    [0.48908630487487303]
# accuracy                                           [0.8892261001517451]
# precision_score_weighted                           [0.8685465963604281]
# precision_score_micro                              [0.8892261001517451]
# AUC_weighted                                        [0.903152652510804]
# average_precision_score_macro                      [0.7541001996881196]
#
#                                  a1260661-f32d-4b9f-9ced-4c0482edcf5e_6  \
# matthews_correlation                                [0.489465214911654]
# weighted_accuracy                                  [0.7786735638656799]
# precision_score_macro                                [0.66781409523345]
# average_precision_score_micro                      [0.9099933007494599]
# recall_score_weighted                              [0.7942336874051593]
# balanced_accuracy                                   [0.856907142208811]
# recall_score_macro                                  [0.856907142208811]
# f1_score_weighted                                  [0.8292387627614369]
# average_precision_score_weighted                   [0.9431141052899573]
# norm_macro_recall                                  [0.7138142844176221]
# AUC_micro                                          [0.9026005742825498]
# log_loss                                          [0.39106325681293364]
# recall_score_micro                                 [0.7942336874051593]
# f1_score_micro                                     [0.7942336874051593]
# AUC_macro                                          [0.9233782905156461]
# f1_score_macro                                     [0.6876122157899153]
# accuracy                                           [0.7942336874051593]
# precision_score_weighted                           [0.9178178826913468]
# precision_score_micro                              [0.7942336874051593]
# AUC_weighted                                       [0.9233782905156461]
# average_precision_score_macro                      [0.7807737245773432]
#
#                                  a1260661-f32d-4b9f-9ced-4c0482edcf5e_5  \
# matthews_correlation                              [0.47077965319103915]
# weighted_accuracy                                  [0.9619470207827714]
# precision_score_macro                              [0.7856451172940535]
# average_precision_score_micro                      [0.9789389178388146]
# recall_score_weighted                               [0.908649468892261]
# balanced_accuracy                                   [0.693976256235563]
# recall_score_macro                                  [0.693976256235563]
# f1_score_weighted                                   [0.899959550454415]
# average_precision_score_weighted                   [0.9492172134275333]
# norm_macro_recall                                 [0.38795251247112605]
# AUC_micro                                          [0.9779290367296751]
# log_loss                                          [0.20462013175825502]
# recall_score_micro                                  [0.908649468892261]
# f1_score_micro                                      [0.908649468892261]
# AUC_macro                                          [0.9388252597495217]
# f1_score_macro                                     [0.7277105470003671]
# accuracy                                            [0.908649468892261]
# precision_score_weighted                           [0.8973758906640772]
# precision_score_micro                               [0.908649468892261]
# AUC_weighted                                       [0.9388252597495217]
# average_precision_score_macro                      [0.8006349647033797]
#
#                                  a1260661-f32d-4b9f-9ced-4c0482edcf5e_7
# matthews_correlation                              [0.47805766735773875]
# weighted_accuracy                                  [0.9679994692811393]
# precision_score_macro                              [0.8065451980757572]
# average_precision_score_micro                      [0.9760584861374465]
# recall_score_weighted                              [0.9119878603945372]
# balanced_accuracy                                  [0.6863829010812322]
# recall_score_macro                                 [0.6863829010812322]
# f1_score_weighted                                  [0.9013350533065821]
# average_precision_score_weighted                   [0.9480633299225389]
# norm_macro_recall                                 [0.37276580216246447]
# AUC_micro                                          [0.9758368429657296]
# log_loss                                          [0.21382270165851136]
# recall_score_micro                                 [0.9119878603945372]
# f1_score_micro                                     [0.9119878603945372]
# AUC_macro                                          [0.9290011799639528]
# f1_score_macro                                     [0.7267246191790099]
# accuracy                                           [0.9119878603945372]
# precision_score_weighted                           [0.9005211086889047]
# precision_score_micro                              [0.9119878603945372]
# AUC_weighted                                       [0.9290011799639528]
# average_precision_score_macro                      [0.8044713126721892]
#
# [21 rows x 37 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/a1260661-f32d-4b9f-9ced-4c0482edcf5e/model_data
# Downloaded azureml/a1260661-f32d-4b9f-9ced-4c0482edcf5e/model_data, 1 files out of an estimated total of 1

# %%
import azureml.train.automl.core.shared.constants

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /anaconda/envs/automl-env3/lib/python3.9/site-packages (2.1.4)
# Requirement already satisfied: numpy in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from xgboost) (1.23.5)
# Requirement already satisfied: nvidia-nccl-cu12 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from xgboost) (2.26.5)
# Requirement already satisfied: scipy in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from xgboost) (1.10.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in /anaconda/envs/automl-env3/lib/python3.9/site-packages (6.0.1)
# Requirement already satisfied: narwhals>=1.15.1 in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from plotly) (1.38.2)
# Requirement already satisfied: packaging in /anaconda/envs/automl-env3/lib/python3.9/site-packages (from plotly) (24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from azureml.core import Workspace, Experiment
#from azureml.core.experiment import Experiment
from azureml.train.automl.run import AutoMLRun

best_model, fitted_model = pipeline.get_output()
best_model.register_model(model_name = 'automl_best_model.pkl', model_path='outputs/')

print(best_model)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 4
#       1 import pickle
#       3 with open(best_model_output._path_on_datastore, "rb" ) as f:
# ----> 4     best_model = pickle.load(f)
#       5 best_model
#
# AttributeError: Can't get attribute 'XGBoostLabelEncoder' on <module 'xgboost.compat' from '/anaconda/envs/automl-env3/lib/python3.9/site-packages/xgboost/compat.py'>

# %%
#import pickle

#with open(best_model_output._path_on_datastore, "rb" ) as f:
#    best_model = pickle.load(f)
#best_model

# %%
#best_model.steps
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 best_model.steps
#
# NameError: name 'best_model' is not defined

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_test.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
